# %% [markdown]
# # BLOCO 5: Aula 11
#
# * link https://drive.google.com/file/d/1LJnjQ9d0hDZimffYxOUyI-Mlp9NRyk3d/view
#
# * link do quadro com resumão https://gitlab.com/simoesusp/disciplinas/-/blob/master/SSC0713-Sistemas-Evolutivos-Aplicados-a-Robotica/MaterialAulaDistancia/LousaImagens_PrimeiroSemestre2021/Evolutivos_ESTRATEGIAS_AG03.svg

# %% [markdown]
# ## Enxames (swarm)
#
# * aula com o Matheus Luis Oliveira da Silva que apresentou o código dele das abelhas evolutivas, explicou como funciona e passou alguns comentários da prática de swarm

# %%
# Exemplo do código das abelhas rodando para ilustrar

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('swarm_abelhas.png')
imgplot = plt.imshow(img)
plt.show()
