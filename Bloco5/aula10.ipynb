# %% [markdown]
# # BLOCO 5: Aula 10
#
# * link https://drive.google.com/file/d/1GlBfaybrS_GHhazd3vBzfk2ZEqGyMNVP/view
#
# * link do quadro com resumão https://gitlab.com/simoesusp/disciplinas/-/blob/master/SSC0713-Sistemas-Evolutivos-Aplicados-a-Robotica/MaterialAulaDistancia/LousaImagens_PrimeiroSemestre2021/Evolutivos_ESTRATEGIAS_AG03.svg

# %% [markdown]
# ## Algoritmos evolutivos (resumo)
#
# * Revisão: etapas dos alg evolutivos
#     1. Inicia populacao
#     2. Avaliação (normalmente a etapa mais lenta)
#     3. Seleção
#     4. Crossover
#     5. Mutação
#     6. Rearranjo da população

# %% [markdown]
# ## Sistemas
#
# ### Sistema tradicional
#
# * Possíveis soluções -> problema
#
# - Tentar exaustivamente **todas as possíveis soluções** e escolher a mais adequada
#
# ### Algoritimos genéticos
#
# * possiveis soluções -> grupo de soluções -> problema
# *                           |-> combinação das melhores soluções
# *                                   |-> outros grupo de soluçẽos -> problema
#
# - Teste de um critério definido e introompimento do processo quando uma **solução aceitável** é produzida
#
# ### Sistema evolutivo robótico
#
# * ambiente -> agente -> combinação dos melhores agentes -> mais agentes -> ambiente
#
# - o que são esses agentes? eles são quem farão a ação no ambiente que queremos que tenham a melhor solução
#     - quanto mais pontos esses agentes fizerem, melhor o fitness (mais proximo da melhor solução)
#
# * Teste de um critério definido até que um **desempenho aceitável** seja produzido

# %% [markdown]
# ## Inteligência de Enxames
#
# * Exames: Descentralizados
#     * manter pelo menso dois alg ev, um de supervisão para avaliar e proteger os indivíduos e o outro para manter tudo o ag rodando normalmente
#     * podemos distribuir o processamento do sistema evolutivo, a função de avaliação está distribuida nos robôs (circulos na imagem abaixo) enquanto a de seleção NÃO está distribuida, ela ocorre simultaneamente em todos os robos

# %%
# Esquema de um enxame descentralizado com distribuição do ag

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('Enxames_descentralizados.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# > o que é um enxame?
#
# * denotamos: Um enxame é um conjunto de Agentes que se comunicam (direta ou indiretamente)
#     * coletivamente resolvem um problema (colaboram entre sim)
#
# - muita inspiração biológica
#     - estamos procurando colaborações, um "senso" artificial de sobrevivência relacionado com o trabalho em conjunto
