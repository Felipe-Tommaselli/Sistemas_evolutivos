# %% [markdown]
# # BLOCO 5: Aula 12
#
# * link https://drive.google.com/file/d/1faWAVpnvNxBpCBb0ixFqgkFa0qt31k4Y/view
#
# * link do quadro com resumão https://gitlab.com/simoesusp/disciplinas/-/blob/master/SSC0713-Sistemas-Evolutivos-Aplicados-a-Robotica/MaterialAulaDistancia/LousaImagens_PrimeiroSemestre2021/Evolutivos_ESTRATEGIAS_AG03.svg

# %% [markdown]
# > discussões iniciais
#
# - Lucas roris e o professor estavam discutindo sobre a função de avaliação, trocaram uma ideia sobre como montar uma boa função de avaliação
#     - Lucas veio com umas ideias meio tortas sobre usar um elemento aleatório nela
#     - ta mexendo com grafos por algum motivo
#     - tem um role de uma proteina com cancer, top dms!
#     - la pros 20 min

# %% [markdown]
# ## Swarm
#
# * Passou sobre os slides com algumas demonstrações legaiszinhas
#     * embaixo a foto de um sistema robótico evolutivo com rede neural

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('sistema_evolutivo_robotico.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# * falou sobre alterações diretas e indiretas no sistema (Como as abelhas que largam feromoneios por onde andam)
#     * solução indireta = estigmetria
#
# - em um enxame:
#     - A inteligenia do sistema NÃO esta distribuida nos individuos
#     - A inteligencia NÃO está programada em nenhum lugar, ele nem se quer existe
#
# * o que acontece é: para cada individuo há um código (igual ou muito parecido) COPIADO para cada um deles, ou seja, não um códiog geral que foi distribuido, há UM código copiado para todos os individuos (ou quase isso) que no olhar macroscopico faz coisas impressionantes!
#     * aula inteira basicamente nessa discussão, acaba sendo meio contra-intuitivo
#
# * nas formigas, os ovos que a rainha bota são todos iguais geneticamente, ou seja, o que vai decidir se a formigua será operária, princesa, soldado etc é o TIPO DE ALIMENTAÇÃO.
#     * ou seja, há um fator externo que vai decidir o comportamento individual, isso causará reações para estresses e mudanças externas em um sistema
#         * exemplo, se passamos veneno no formigueiro, os próximos ovos serão alimentados com mais geleia real e gerará mais princesas para criar novos formigueiros e superar o estresse
#         * em tempos de mais tranquilidade e expansão, espera-se gerar mais operárias para aumentar a qualidade de vida no formigueiro e pegar mais comida
